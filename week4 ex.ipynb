# %% [markdown]
# <h1> Introduction </h1>
#
# <h2>Problem objectives</h2>
#
# The objective of this project is to find out the best neigbohord to set up a restaurant in Toronto
#
# We will take into consideration
# <li>Toronto's Population</li>
# <li>Toronto Demographics by postal codes</li>
# <li>Toronto Average income post taxes by postal codes</li>
# <li>List of all competitors in that location by postal code</li>
#
#
# <h1>Data Used</H1>
#
# <h2>Data1: Toronto Neighborhoods & Demography</h2>
# <li>List of Toronto's neighborhoods by Postal Code</li>
# The Wikipedia dataset of the list of neighborhoods will be used:
# https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
# <li>List of Toroto neighborhood population broken down by Postal Code</li>
# https://www12.statcan.gc.ca/census-recensement/2016/dp-pd/hlt-fst/pd-pl/Tables/File.cfm?T=1201&SR=1&RPP=9999&PR=0&CMA=0&CSD=0&S=22&O=A&Lang=Eng&OFT=CSV
#
# <h2>Data2: Toronto Neighborhoods Income & Crime</h2>
# <li>Canandian National Average on Net Income</li>
# https://www150.statcan.gc.ca/n1/daily-quotidien/180313/dq180313a-eng.htm
#
# <li>Average Net Income of Toronto Neighborhoods</li>
# https://www150.statcan.gc.ca/n1/daily-quotidien/180313/t001a-eng.htm
#
# <li>crimes of Toronto Neighborhoods from Tronto Police Data/li>
# https://www.kaggle.com/kapastor/toronto-police-data-crime-rates-by-neighbourhood
#
# <h2>Data3: Toronto existing restaurants with their cuisines & farmers markets</h2>
# <li>Details of Farmers Market : https://data.ontario.ca/en/dataset/farmers-markets</li>
# <li>List of cusines : https://en.wikipedia.org/wiki/Cuisine_in_Toronto<li>
#
# <h2>Data 4: List of all Restaurant venues in Toronto neighborhoods by Postal Code</h2>
# https://foursquare.com/developers/apps
